# %% [markdown]
# **Mount drive to colab**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Import necessary libraries**

# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import nltk

nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# ...

# %% [markdown]
# **Reading the dataset**

# %%
df = pd.read_csv('/content/drive/MyDrive/toxicprediction.csv')

# %%
df.head()
# Out:
#                                             ocr_text
# 0  LOOK THERE MY FRIEND LIGHTYEAR NOW ALL SOHALIK...
# 1  The best of #10 YearChallenge! Completed in le...
# 2  Sam Thorne @Strippin ( Follow Follow Saw every...
# 3              10 Year Challenge - Sweet Dee Edition
# 4  10 YEAR CHALLENGE WITH NO FILTER 47 Hilarious ...

# %% [markdown]
# **Preprocess text**

# %%
# create preprocess_text function
def preprocess_text(text):

    # Tokenize the text

    tokens = word_tokenize(text.lower())




    # Remove stop words

    filtered_tokens = [token for token in tokens if token not in stopwords.words('english')]




    # Lemmatize the tokens

    lemmatizer = WordNetLemmatizer()

    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]




    # Join the tokens back into a string

    processed_text = ' '.join(lemmatized_tokens)

    return processed_text

# %%
# apply the function df

df['ocr_text'] = df['ocr_text'].apply(preprocess_text)
df
# Out:
#                                                ocr_text
# 0     look friend lightyear sohalikut trend play 10 ...
# 1     best # 10 yearchallenge ! completed le 4 year ...
# 2     sam thorne @ strippin ( follow follow saw ever...
# 3                 10 year challenge - sweet dee edition
# 4     10 year challenge filter 47 hilarious 10 year ...
# ...                                                 ...
# 2721  talked iagreed dinner [ oulld ] ready time future
# 2722  look playiing dbeit mavorite sport _ cross-cou...
# 2723                                        want spin ?
# 2724      aiterayirldies oryan hodystays harm ? mv dick
# 2725                 whedpoube bawwy @ tobe widh damily
#
# [2726 rows x 1 columns]

# %% [markdown]
# **initialize NLTK sentiment analyzer**

# %%
analyzer = SentimentIntensityAnalyzer()


# create get_sentiment function

def get_sentiment(text):

    scores = analyzer.polarity_scores(text)

    sentiment = 0 if scores['pos'] > 0 else 1

    return sentiment

# %% [markdown]
# **Predicting toxic or not for given text**

# %%
get_sentiment("The best of #10 YearChallenge! Completed in less the 4 years. Kudus to @narendramodi ji 8:05 PM - 16 Jan 2019 from Mumbai  India")
# Out:
# 0

# %%
df['sentiment'] = df['ocr_text'].apply(get_sentiment)

df
# Out:
#                                                ocr_text  sentiment
# 0     look friend lightyear sohalikut trend play 10 ...          0
# 1     best # 10 yearchallenge ! completed le 4 year ...          0
# 2     sam thorne @ strippin ( follow follow saw ever...          0
# 3                 10 year challenge - sweet dee edition          0
# 4     10 year challenge filter 47 hilarious 10 year ...          0
# ...                                                 ...        ...
# 2721  talked iagreed dinner [ oulld ] ready time future          0
# 2722  look playiing dbeit mavorite sport _ cross-cou...          1
# 2723                                        want spin ?          0
# 2724      aiterayirldies oryan hodystays harm ? mv dick          1
# 2725                 whedpoube bawwy @ tobe widh damily          1
#
# [2726 rows x 2 columns]
